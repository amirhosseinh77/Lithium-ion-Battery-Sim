# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from elements.fullModel import LumpedModel

# %%
thermal_model = LumpedModel(T=25, dt=1)

# %%
print(thermal_model.Tc,thermal_model.Ts)
# Out:
# 25 25

# %%
temps = []

for i in range(100):
    thermal_model.updateTemp(100,20)
    temps.append([thermal_model.Tc, thermal_model.Ts])
    print(thermal_model.Tc,thermal_model.Ts)

temps = np.array(temps)
# Out:
# 25.09516258196404 24.54682688269496
# 25.138144123002576 24.18442513987299
# 25.142548344063886 23.89161130384339
# 25.11866852740609 23.652274786276752
# 25.074285294788353 23.45415828081926
# 25.015272406993404 23.287931547532576
# 24.946056772839167 23.146487998142437
# 24.869967743781203 23.024410481493042
# 24.789502331503414 22.91756556385461
# 24.706526577384572 22.822795391630507
# 24.622428435986073 22.737683660925185
# 24.538233838812086 22.660377866169625
# 24.454694797862878 22.589454288999796
# 24.372356277019588 22.523815445731834
# 24.29160694061233 22.462612185318918
# 24.21271765926396 22.405184508130223
# 24.135870719580513 22.351016602427883
# 24.06118197532716 22.29970267875721
# 23.9887176393534 22.25092100517476
# 23.918507006680585 22.204414171020858
# 23.850552088677183 22.159974081415502
# 23.78483490245858 22.117430544980493
# 23.721322980586915 22.076642590928618
# 23.65997353016545 22.037491859467092
# 23.600736567156506 21.999877567275554
# 23.543557273331505 21.963712669665792
# 23.488377763708762 21.92892093204517
# 23.43513840711023 21.895434692424722
# 23.38377880812517 21.863193149203912
# 23.334238532688772 21.832141048327223
# 23.286457639679277 21.802227674181463
# 23.240377065898148 21.773406071593456
# 23.195938900377797 21.745632443748143
# 23.15308657528984 21.718865684107406
# 23.111764994142195 21.693067010480515
# 23.07192061295381 21.66819967704543
# 23.033501486299834 21.64422874592903
# 22.99645728723793 21.621120904366137
# 22.96073930793881 21.598844316807956
# 22.926300446182946 21.577368503895872
# 22.89309518162518 21.55666424214973
# 22.86107954477211 21.53670347968827
# 22.830211080891395 21.517459264415148
# 22.800448810521573 21.49890568195154
# 22.771753187833337 21.481017801240505
# 22.74408605777685 21.463771626237662
# 22.7174106127098 21.447144052474954
# 22.69169134901931 21.431112827567045
# 22.666894024113542 21.415656514945148
# 22.642985614054865 21.400754460266736
# 22.61993427202826 21.386386760074252
# 22.597709287779438 21.37253423237081
# 22.576281048112858 21.359178388853316
# 22.555620998506463 21.346301408598634
# 22.53570160587518 21.333886113040588
# 22.516496322496696 21.321915942107953
# 22.497979551099355 21.310374931418337
# 22.48012661110213 21.299247690441835
# 22.462913705989227 21.28851938156314
# 22.446317891796966 21.278175699982057
# 22.430317046686763 21.26820285440123
# 22.414889841575857 21.25858754845689
# 22.400015711795756 21.249316962853726
# 22.385674829747682 21.24037873816944
# 22.37184807852381 21.23176095829797
# 22.35851702646321 21.223452134503077
# 22.34566390261159 21.215441190056442
# 22.333271573054482 21.207717445436195
# 22.321323518094083 21.200270604063462
# 22.30980381024066 21.19309073855588
# 22.29869709299018 21.18616827747819
# 22.287988560360706 21.17949399257101
# 22.277663937160767 21.173058986440008
# 22.267709459963957 21.166854680688207
# 22.25811185876466 21.160872804475225
# 22.248858339290738 21.155105383487726
# 22.239936565949762 21.149544729306104
# 22.23133464538628 21.144183429153014
# 22.223041110628216 21.139014336009886
# 22.215044905801427 21.134030559088124
# 22.20733537139206 21.129225454642203
# 22.199902230037146 21.124592617112324
# 22.192735572824507 21.12012587058476
# 22.18582584608373 21.115819260558503
# 22.179163838650666 21.11166704600712
# 22.172740669588414 21.107663691725335
# 22.166547776348548 21.103803860949988
# 22.160576903356688 21.100082408245605
# 22.154820091007306 21.09649437264505
# 22.149269665053048 21.09303497103612
# 22.14391822637444 21.089699591785223
# 22.138758641116365 21.086483788589728
# 22.13378403117814 21.08338327455065
# 22.128987765044528 21.080393916457886
# 22.124363448945452 21.077511729280342
# 22.119904918332665 21.074732870853556
# 22.115606229661953 21.072053636757815
# 22.111461652469966 21.06947045537989
# 22.107465661735112 21.066979883151802
# 22.1036129305123 21.064578599960303

# %%
plt.subplot(2,1,1)
plt.plot(temps[:,0])
plt.ylabel('Core Temp')
plt.grid()
plt.subplot(2,1,2)
plt.plot(temps[:,1])
plt.ylabel('sSurface Temp')
plt.grid()

# %% [markdown]
# # Full Model

# %%
from elements.fullModel import LithiumIonBattery

cell = LithiumIonBattery()

# %%
temps = []

for i in range(100):
    cell.updateModel(100, 20)
    temps.append([cell.ECM.z_k, cell.ThM.Tc])

temps = np.array(temps).reshape(-1,2)

plt.subplot(2,1,1)
plt.plot(temps[:,0])
plt.ylabel('State of Charge')
plt.grid()
plt.subplot(2,1,2)
plt.plot(temps[:,1])
plt.ylabel('Core Temp')
plt.grid()
